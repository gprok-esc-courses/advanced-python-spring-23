# %%
import pandas as pd

# %%
train_df = pd.read_csv('train.csv')

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import seaborn as sns
import matplotlib.pylab as plt

# %%
x_data = train_df[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch']]

# %%
x_corr = train_df.corr()
# Out:
# /var/folders/3q/c3scs9pj6jddvd8kr62_g0280000gn/T/ipykernel_33246/920167615.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x_corr = train_df.corr()

# %%
x_corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
hm = sns.heatmap(x_corr)
plt.show()

# %%
sns.pointplot(x='Pclass', y='Survived', hue='Sex', data=train_df, 
             palette={'male': 'blue', 'female': 'orange'}, markers=['o', 'x'], linestyles=['-', '--'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/categorical.py:1728: UserWarning: You passed a edgecolor/edgecolors ((1.0, 0.6470588235294118, 0.0)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,
# <AxesSubplot: xlabel='Pclass', ylabel='Survived'>

# %%
train_df['AgeCat'] = None

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked AgeCat
# 0      0         A/5 21171   7.2500   NaN        S   None
# 1      0          PC 17599  71.2833   C85        C   None
# 2      0  STON/O2. 3101282   7.9250   NaN        S   None
# 3      0            113803  53.1000  C123        S   None
# ...

# %%
train_df.loc[train_df.Age <= 5, ['AgeCat']] = 'Baby'

# %%
train_df.loc[train_df.Age.between(6, 13), ['AgeCat']] = 'Child'

# %%
train_df.loc[train_df.Age.between(13, 22), ['AgeCat']] = 'Teenager'

# %%
train_df.loc[train_df.Age.between(22, 36), ['AgeCat']] = 'Young'

# %%
train_df.loc[train_df.Age.between(36, 50), ['AgeCat']] = 'Middle Age'

# %%
train_df.loc[train_df.Age >= 50, ['AgeCat']] = 'Old'

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked      AgeCat
# 0      0         A/5 21171   7.2500   NaN        S       Young
# 1      0          PC 17599  71.2833   C85        C  Middle Age
# 2      0  STON/O2. 3101282   7.9250   NaN        S       Young
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  AgeCat       714 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
dummy_df = train_df[['PassengerId', 'AgeCat']]

# %%
dummy_df = pd.get_dummies(dummy_df)

# %%
dummy_df.head()
# Out:
#    PassengerId  AgeCat_Baby  AgeCat_Child  AgeCat_Middle Age  AgeCat_Old  \
# 0            1            0             0                  0           0
# 1            2            0             0                  1           0
# 2            3            0             0                  0           0
# 3            4            0             0                  0           0
# 4            5            0             0                  0           0
#
#    AgeCat_Teenager  AgeCat_Young
# 0                0             1
# 1                0             0
# 2                0             1
# 3                0             1
# 4                0             1
